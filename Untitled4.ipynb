# %% [markdown]
# <a href="https://colab.research.google.com/github/komal2267g/Deep-Learning_LabWork/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop, Adam


# ----------------------------------------
# Load Fashion-MNIST Dataset
# ----------------------------------------

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the images

x_train = x_train / 255.0
x_test = x_test / 255.0

print("Training Samples =", len(x_train))
print("Testing Samples =", len(x_test))


# ----------------------------------------
# Create MLP Model
# ----------------------------------------

def create_model():

    model = Sequential([

        Flatten(input_shape=(28,28)),

        Dense(
            128,
            activation="relu"
        ),

        Dense(
            10,
            activation="softmax"
        )

    ])

    return model


# ----------------------------------------
# Define Optimizers
# ----------------------------------------

optimizers = {

    "SGD":SGD(),

    "SGD + Momentum":SGD(
        learning_rate=0.01,
        momentum=0.9
    ),

    "RMSProp":RMSprop(),

    "Adam":Adam()

}


# ----------------------------------------
# Store Results
# ----------------------------------------

results = {}

histories = {}


# ----------------------------------------
# Train Models
# ----------------------------------------

for name,optimizer in optimizers.items():

    print("\nTraining using",name,"\n")

    model = create_model()

    model.compile(

        optimizer=optimizer,

        loss="sparse_categorical_crossentropy",

        metrics=["accuracy"]

    )


    start_time = time.time()


    history = model.fit(

        x_train,
        y_train,

        epochs=10,

        batch_size=128,

        validation_data=(x_test,y_test),

        verbose=0

    )


    training_time = time.time()-start_time


    test_loss,test_accuracy = model.evaluate(

        x_test,
        y_test,
        verbose=0

    )


    results[name]={

        "Training Loss":
        history.history["loss"][-1],

        "Validation Loss":
        history.history["val_loss"][-1],

        "Accuracy":
        test_accuracy,

        "Training Time":
        training_time,

        "Epochs":
        10

    }


    histories[name]=history


# ----------------------------------------
# Print Results
# ----------------------------------------

print("\n\nFINAL RESULTS\n")

for name in results:

    print("-------------------------------------")

    print(name)

    print()

    print("Training Loss =",
          results[name]["Training Loss"])

    print()

    print("Validation Loss =",
          results[name]["Validation Loss"])

    print()

    print("Accuracy =",
          results[name]["Accuracy"])

    print()

    print("Training Time =",
          results[name]["Training Time"])

    print()

    print("Epochs =",
          results[name]["Epochs"])

    print("-------------------------------------")


# ----------------------------------------
# LOSS CURVE
# ----------------------------------------

plt.figure(figsize=(8,5))

for name in histories:

    plt.plot(

        histories[name].history["loss"],
        label=name

    )


plt.xlabel("Epochs")
plt.ylabel("Training Loss")
plt.title("Training Loss Comparison")

plt.legend()
plt.grid(True)

plt.show()


# ----------------------------------------
# ACCURACY CURVE
# ----------------------------------------

plt.figure(figsize=(8,5))

for name in histories:

    plt.plot(

        histories[name].history["accuracy"],
        label=name

    )


plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.title("Training Accuracy Comparison")

plt.legend()
plt.grid(True)

plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Samples = 60000
# Testing Samples = 10000
#
# Training using SGD
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training using SGD + Momentum
#
#
# Training using RMSProp
#
#
# Training using Adam
#
#
#
# FINAL RESULTS
#
# -------------------------------------
# SGD
#
# Training Loss = 0.46390363574028015
#
# Validation Loss = 0.49137476086616516
#
# Accuracy = 0.8282999992370605
#
# Training Time = 27.244868516921997
#
# Epochs = 10
# -------------------------------------
# -------------------------------------
# SGD + Momentum
#
# ...
